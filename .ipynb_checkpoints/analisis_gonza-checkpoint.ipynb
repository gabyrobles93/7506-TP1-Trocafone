# %%
#importo librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('default')

sns.set(style="whitegrid")

# %%
#cargo csv
events = pd.read_csv('./data/events.csv', low_memory=False)
pd.set_option('display.max_columns', 51)

# %%
#veo como esta formado
events.head()
# Out:
#              timestamp            event    person                        url  \
# 0  2018-05-31 23:38:05  ad campaign hit  0004b0a2  /comprar/iphone/iphone-5s
# 1  2018-05-31 23:38:05     visited site  0004b0a2                        NaN
# 2  2018-05-31 23:38:09   viewed product  0004b0a2                        NaN
# 3  2018-05-31 23:38:40         checkout  0004b0a2                        NaN
# 4  2018-05-29 13:29:25   viewed product  0006a21a                        NaN
#
#        sku              model condition storage           color skus  \
# 0      NaN                NaN       NaN     NaN             NaN  NaN
# 1      NaN                NaN       NaN     NaN             NaN  NaN
# 2   2694.0          iPhone 5s       Bom    32GB  Cinza espacial  NaN
# 3   2694.0          iPhone 5s       Bom    32GB  Cinza espacial  NaN
# 4  15338.0  Samsung Galaxy S8       Bom    64GB         Dourado  NaN
#
#   search_term staticpage campaign_source search_engine channel  \
# 0         NaN        NaN          criteo           NaN     NaN
# 1         NaN        NaN             NaN           NaN    Paid
# 2         NaN        NaN             NaN           NaN     NaN
# 3         NaN        NaN             NaN           NaN     NaN
# 4         NaN        NaN             NaN           NaN     NaN
#
#   new_vs_returning        city      region country device_type  \
# 0              NaN         NaN         NaN     NaN         NaN
# 1              New  Camaragibe  Pernambuco  Brazil  Smartphone
# 2              NaN         NaN         NaN     NaN         NaN
# 3              NaN         NaN         NaN     NaN         NaN
# 4              NaN         NaN         NaN     NaN         NaN
#
#   screen_resolution operating_system_version   browser_version
# 0               NaN                      NaN               NaN
# 1           360x640                Android 6  Chrome Mobile 39
# 2               NaN                      NaN               NaN
# 3               NaN                      NaN               NaN
# 4               NaN                      NaN               NaN

# %%
#me quedo con las columnas que me importan
events_short = events.filter(items=['timestamp','event','person','campaign_source','channel','new_vs_returning'])

# %%
#veo como esta formado
events_short.head()
# Out:
#              timestamp            event    person campaign_source channel  \
# 0  2018-05-31 23:38:05  ad campaign hit  0004b0a2          criteo     NaN
# 1  2018-05-31 23:38:05     visited site  0004b0a2             NaN    Paid
# 2  2018-05-31 23:38:09   viewed product  0004b0a2             NaN     NaN
# 3  2018-05-31 23:38:40         checkout  0004b0a2             NaN     NaN
# 4  2018-05-29 13:29:25   viewed product  0006a21a             NaN     NaN
#
#   new_vs_returning
# 0              NaN
# 1              New
# 2              NaN
# 3              NaN
# 4              NaN

# %%
#cambio timestamp a datetime
#agrego la columna de mes
events_short['timestamp'] = pd.to_datetime(events_short['timestamp'])
events_short['month'] = events_short['timestamp'].dt.month

# %%
#events_short['month'] = events_short['timestamp'].dt.month
#events_short['day'] = events_short['timestamp'].dt.day
#events_short.sort_values(by=['person', 'timestamp'], ascending=True)

# %%
#quiero analizar usuarios nuevos de los viejos
#elimino todos las filas en las q not enga esa informacion
new_vs_returning = events_short.dropna(subset=['new_vs_returning'])

# %%
#veo como esta formada
new_vs_returning.head()
# Out:
#              timestamp         event    person campaign_source  channel  \
# 1  2018-05-31 23:38:05  visited site  0004b0a2             NaN     Paid
# 5  2018-05-29 13:29:26  visited site  0006a21a             NaN     Paid
# 9  2018-04-09 20:12:31  visited site  000a54b2             NaN     Paid
# 16 2018-05-24 11:21:07  visited site  000a54b2             NaN     Paid
# 45 2018-04-06 05:12:05  visited site  00184bf9             NaN  Organic
#
#    new_vs_returning  month
# 1               New      5
# 5               New      5
# 9               New      4
# 16        Returning      5
# 45              New      4

# %%
new_vs_returning['new_vs_returning'].value_counts()
# Out:
# Returning    60480
# New          26898
# Name: new_vs_returning, dtype: int64

# %%
new_vs_returning['channel'].value_counts()
# Out:
# Paid        44193
# Direct      18522
# Organic     12348
# Referral    11384
# Social        846
# Email          76
# Unknown         9
# Name: channel, dtype: int64

# %%
#creo dos dataframes nuevos uno con todos los usuarios returning y otro con la data de 
#todos los usuarios nuevos
#g = new_vs_returning.groupby(['month', 'channel']).agg({'new_vs_returning' : 'count'})
new = new_vs_returning.loc[new_vs_returning['new_vs_returning'] == 'New']
returning = new_vs_returning.loc[new_vs_returning['new_vs_returning'] == 'Returning']

# %%
#agrupo ambos dataframes por mes y canal
new = new.groupby(['month', 'channel']).agg({'new_vs_returning' : 'count'})
returning = returning.groupby(['month' , 'channel']).agg({'new_vs_returning' : 'count'})

# %%
#transformo los canales en columnas
new.unstack()
# Out:
#         new_vs_returning
# channel           Direct Email Organic    Paid Referral Social Unknown
# month
# 1                   51.0   NaN   154.0   287.0     12.0   13.0     NaN
# 2                   55.0   NaN   109.0   317.0     11.0    7.0     NaN
# 3                  116.0   1.0   270.0   670.0     26.0   42.0     NaN
# 4                  172.0   NaN   440.0   952.0     44.0   19.0     NaN
# 5                 1027.0   7.0  2581.0  8459.0    341.0  188.0     1.0
# 6                  786.0   2.0  2155.0  7124.0    250.0  209.0     NaN

# %%
returning.unstack()
# Out:
#         new_vs_returning
# channel           Direct Email Organic     Paid Referral Social Unknown
# month
# 1                  567.0   1.0   198.0    424.0    390.0   38.0     NaN
# 2                  764.0   3.0   201.0    879.0    413.0   31.0     NaN
# 3                 1745.0  16.0   526.0   2684.0   1069.0   82.0     NaN
# 4                 3376.0  12.0  1064.0   4654.0   1896.0   20.0     1.0
# 5                 7187.0  28.0  3189.0  12173.0   4870.0   79.0     7.0
# 6                 2676.0   6.0  1461.0   5570.0   2062.0  118.0     NaN

# %%
#hago un pivot de table, transofmrando mes en indice, chanel en columnas y new_vs_returning como valores de ambos indices
new = new.pivot_table(index='month', columns='channel', values='new_vs_returning')
returning = returning.pivot_table(index='month', columns='channel', values='new_vs_returning')

# %%
new
# Out:
# channel  Direct  Email  Organic    Paid  Referral  Social  Unknown
# month
# 1          51.0    NaN    154.0   287.0      12.0    13.0      NaN
# 2          55.0    NaN    109.0   317.0      11.0     7.0      NaN
# 3         116.0    1.0    270.0   670.0      26.0    42.0      NaN
# 4         172.0    NaN    440.0   952.0      44.0    19.0      NaN
# 5        1027.0    7.0   2581.0  8459.0     341.0   188.0      1.0
# 6         786.0    2.0   2155.0  7124.0     250.0   209.0      NaN

# %%
new.plot.bar()

# %%
returning.plot.bar()

# %%
#me quedo con los eventos de conversiones y checkout
check_conv = events_short.loc[(events_short['event'] == 'conversion') | (events_short['event'] == 'checkout')]

# %%
check_conv
# Out:
#                   timestamp       event    person campaign_source channel  \
# 3       2018-05-31 23:38:40    checkout  0004b0a2             NaN     NaN
# 7       2018-05-29 13:29:35    checkout  0006a21a             NaN     NaN
# 44      2018-05-24 11:34:32    checkout  000a54b2             NaN     NaN
# 85      2018-04-06 05:14:58    checkout  00184bf9             NaN     NaN
# 86      2018-04-06 05:18:15    checkout  00184bf9             NaN     NaN
# 94      2018-05-04 18:50:21    checkout  00184bf9             NaN     NaN
# 95      2018-05-17 04:45:15    checkout  00184bf9             NaN     NaN
# 103     2018-05-17 00:11:26    checkout  0019c395             NaN     NaN
# 110     2018-06-08 12:19:50    checkout  001bb7eb             NaN     NaN
# 114     2018-05-29 12:56:27    checkout  001f1653             NaN     NaN
# 137     2018-02-01 23:33:52    checkout  00204059             NaN     NaN
# 204     2018-02-15 22:10:01    checkout  00204059             NaN     NaN
# 216     2018-02-16 00:25:21    checkout  00204059             NaN     NaN
# 219     2018-02-16 00:27:43    checkout  00204059             NaN     NaN
# 220     2018-03-20 17:46:12  conversion  00204059             NaN     NaN
# 225     2018-05-19 03:36:24    checkout  00204059             NaN     NaN
# 226     2018-06-12 19:44:12    checkout  0020f73c             NaN     NaN
# 233     2018-05-30 16:05:55    checkout  0024a82b             NaN     NaN
# 257     2018-05-28 22:52:08    checkout  0024ad28             NaN     NaN
# 271     2018-06-07 21:42:39    checkout  00269e77             NaN     NaN
# 299     2018-06-14 20:30:48    checkout  0026fd72             NaN     NaN
# 326     2018-06-12 23:44:34    checkout  0027c344             NaN     NaN
# 334     2018-06-15 00:41:19    checkout  00283a9e             NaN     NaN
# 361     2018-05-30 18:35:08    checkout  002932b1             NaN     NaN
# 366     2018-05-16 22:42:30    checkout  002cecfa             NaN     NaN
# 367     2018-06-09 05:28:39    checkout  002f3084             NaN     NaN
# 386     2018-05-28 19:53:54    checkout  00300ace             NaN     NaN
# 390     2018-06-13 16:14:07    checkout  00344c0a             NaN     NaN
# 480     2018-06-07 17:30:57    checkout  003857f6             NaN     NaN
# 489     2018-06-06 21:56:46    checkout  003f561a             NaN     NaN
# ...                     ...         ...       ...             ...     ...
# 1010700 2018-05-17 22:10:47    checkout  ffb967e2             NaN     NaN
# 1010722 2018-06-01 20:25:48    checkout  ffbae174             NaN     NaN
# 1010730 2018-06-08 15:11:08    checkout  ffc0fa7a             NaN     NaN
# 1010734 2018-06-05 17:04:28    checkout  ffc42079             NaN     NaN
# 1010763 2018-06-12 17:32:34    checkout  ffcfcbf4             NaN     NaN
# 1010767 2018-06-05 10:56:23    checkout  ffcfd168             NaN     NaN
# 1010779 2018-05-31 01:38:52    checkout  ffd0be6e             NaN     NaN
# 1010787 2018-05-21 00:40:19    checkout  ffd33f13             NaN     NaN
# 1010801 2018-05-17 12:35:45    checkout  ffd85102             NaN     NaN
# 1010809 2018-05-31 09:03:54    checkout  ffd9b5f9             NaN     NaN
# 1010838 2018-05-21 19:17:00    checkout  ffd9e195             NaN     NaN
# 1010848 2018-05-30 18:11:44    checkout  ffdcf469             NaN     NaN
# 1010879 2018-05-16 18:34:59    checkout  ffe006ea             NaN     NaN
# 1010887 2018-06-04 22:42:11    checkout  ffe129fe             NaN     NaN
# 1010948 2018-05-25 15:47:07    checkout  ffe1bfe7             NaN     NaN
# 1010983 2018-06-15 20:26:28    checkout  ffe1f855             NaN     NaN
# 1011010 2018-06-08 19:21:45    checkout  ffe226f0             NaN     NaN
# 1011014 2018-05-17 13:06:51    checkout  ffe741db             NaN     NaN
# 1011043 2018-06-02 12:43:54    checkout  ffeaaa70             NaN     NaN
# 1011052 2018-06-13 23:59:55    checkout  ffeb3a03             NaN     NaN
# 1011057 2018-06-08 18:28:37    checkout  ffef9da6             NaN     NaN
# 1011180 2018-05-30 19:54:34    checkout  fff0e00c             NaN     NaN
# 1011186 2018-06-08 11:54:27    checkout  fff225f8             NaN     NaN
# 1011204 2018-06-07 22:19:38    checkout  fff229f7             NaN     NaN
# 1011230 2018-05-21 11:11:11    checkout  fff568f7             NaN     NaN
# 1011234 2018-05-25 18:20:05    checkout  fff60213             NaN     NaN
# 1011239 2018-05-28 18:20:25    checkout  fff99b85             NaN     NaN
# 1011247 2018-05-15 18:34:21    checkout  ffff8106             NaN     NaN
# 1011283 2018-06-11 12:31:49    checkout  ffffa8d1             NaN     NaN
# 1011287 2018-06-04 23:18:10    checkout  ffffac8a             NaN     NaN
#
#         new_vs_returning  month
# 3                    NaN      5
# 7                    NaN      5
# 44                   NaN      5
# 85                   NaN      4
# 86                   NaN      4
# 94                   NaN      5
# 95                   NaN      5
# 103                  NaN      5
# 110                  NaN      6
# 114                  NaN      5
# 137                  NaN      2
# 204                  NaN      2
# 216                  NaN      2
# 219                  NaN      2
# 220                  NaN      3
# 225                  NaN      5
# 226                  NaN      6
# 233                  NaN      5
# 257                  NaN      5
# 271                  NaN      6
# 299                  NaN      6
# 326                  NaN      6
# 334                  NaN      6
# 361                  NaN      5
# 366                  NaN      5
# 367                  NaN      6
# 386                  NaN      5
# 390                  NaN      6
# 480                  NaN      6
# 489                  NaN      6
# ...                  ...    ...
# 1010700              NaN      5
# 1010722              NaN      6
# 1010730              NaN      6
# 1010734              NaN      6
# 1010763              NaN      6
# 1010767              NaN      6
# 1010779              NaN      5
# 1010787              NaN      5
# 1010801              NaN      5
# 1010809              NaN      5
# 1010838              NaN      5
# 1010848              NaN      5
# 1010879              NaN      5
# 1010887              NaN      6
# 1010948              NaN      5
# 1010983              NaN      6
# 1011010              NaN      6
# 1011014              NaN      5
# 1011043              NaN      6
# 1011052              NaN      6
# 1011057              NaN      6
# 1011180              NaN      5
# 1011186              NaN      6
# 1011204              NaN      6
# 1011230              NaN      5
# 1011234              NaN      5
# 1011239              NaN      5
# 1011247              NaN      5
# 1011283              NaN      6
# 1011287              NaN      6
#
# [34907 rows x 7 columns]

# %%
check_conv = check_conv.groupby(['month', 'event']).agg({'person' : 'count'})

# %%
check_conv
# Out:
#                   person
# month event
# 1     checkout       331
#       conversion      63
# 2     checkout       441
#       conversion      74
# 3     checkout      1386
#       conversion     265
# 4     checkout      1965
#       conversion     316
# 5     checkout     15645
#       conversion     351
# 6     checkout     13967
#       conversion     103

# %%
check_conv = check_conv.pivot_table(index='month', columns='event', values='person')

# %%
check_conv
# Out:
# event  checkout  conversion
# month
# 1           331          63
# 2           441          74
# 3          1386         265
# 4          1965         316
# 5         15645         351
# 6         13967         103

# %%
check_conv.plot.bar()
